# %% [markdown]
# ## 1

# %%
import pandas as pd #import the library

# %%
myDF= pd.read_csv("/anvil/projects/tdm/data/olympics/athlete_events.csv") #Reading the dataset

# %%
myDF.head() #to view the data in the dataset
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
myDF['Year'] #use myDF to print each year
# Out:
# 0         1992
# 1         2012
# 2         1920
# 3         1900
# 4         1988
#           ...
# 271111    1976
# 271112    2014
# 271113    2014
# 271114    1998
# 271115    2002
# Name: Year, Length: 271116, dtype: int64

# %%
myDF['Year'].value_counts() #count the no. of times year appeared in "year" column
# Out:
# 1992    16413
# 1988    14676
# 2000    13821
# 1996    13780
# 2016    13688
# 2008    13602
# 2004    13443
# 2012    12920
# 1972    11959
# 1984    11588
# 1976    10502
# 1968    10479
# 1964     9480
# 1952     9358
# 1960     9235
# 1980     8937
# 1948     7480
# 1936     7401
# 1956     6434
# 1924     5693
# 1928     5574
# 2014     4891
# 2010     4402
# 2006     4382
# 1920     4292
# 2002     4109
# 1912     4040
# 1998     3605
# 1932     3321
# 1994     3160
# 1908     3101
# 1900     1936
# 1906     1733
# 1904     1301
# 1896      380
# Name: Year, dtype: int64

# %%
myDF['Year'].value_counts().head() #to print the no. of athletes participating in the Olympics during each year.
# Out:
# 1992    16413
# 1988    14676
# 2000    13821
# 1996    13780
# 2016    13688
# Name: Year, dtype: int64

# %%
mycounts = myDF['Year'].value_counts().head()

# %%
#counting the  number of athletes participating in the Olympics during each year & importing matplotlib to show it graphically year wi

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(mycounts.index, mycounts)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## 2

# %%
myDF['NOC'] #to view the NOC data
# Out:
# 0         CHN
# 1         CHN
# 2         DEN
# 3         DEN
# 4         NED
#          ...
# 271111    POL
# 271112    POL
# 271113    POL
# 271114    POL
# 271115    POL
# Name: NOC, Length: 271116, dtype: object

# %%
myDF['NOC'].value_counts() #to count the no. of NOC in the dataframe
# Out:
# USA    18853
# FRA    12758
# GBR    12256
# ITA    10715
# GER     9830
#        ...
# YMD        5
# SSD        3
# UNK        2
# NBO        2
# NFL        1
# Name: NOC, Length: 230, dtype: int64

# %%
myDF.head()
# Out:
#      CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI    IMAGE_NUM TRANSACTION_TP  \
# 0  C00078279         A    M11               P  80031492155            22Y
# 1  C00078279         A    M11             NaN  79031415137             15
# 2  C00078279         A    M11             NaN  79031415137             15
# 3  C00078279         A    M11             NaN  79031415137             15
# 4  C00078287         A     Q1             NaN  79031231889             15
#
#    ENTITY_TP               NAME     CITY STATE  ...         EMPLOYER  \
# 0        NaN      MCKENNON, K R  MIDLAND    MI  ...              NaN
# 1        NaN        OREFFICE, P  MIDLAND    MI  ...  DOW CHEMICAL CO
# 2        NaN          DOWNEY, J  MIDLAND    MI  ...  DOW CHEMICAL CO
# 3        NaN           BLAIR, E  MIDLAND    MI  ...  DOW CHEMICAL CO
# 4        NaN  BLANCHARD, JOHN A  CHICAGO    IL  ...              NaN
#
#   OCCUPATION  TRANSACTION_DT  TRANSACTION_AMT  OTHER_ID TRAN_ID  FILE_NUM  \
# ...

# %%
myDF['NAME']
# Out:
# 0              MCKENNON, K R
# 1                OREFFICE, P
# 2                  DOWNEY, J
# 3                   BLAIR, E
# 4          BLANCHARD, JOHN A
#                  ...
# 308691      PLEMAN, THOMAS J
# 308692    SHEINBAUM, STANLEY
# 308693     PHILLIPS, LEONARD
# 308694     PHILLIPS, BETTY S
# 308695    STUART, HAROLD MRS
# Name: NAME, Length: 308696, dtype: object

# %%
myDF['NAME'].value_counts() 
#to get Which value appears in the "Name" column the most times
# Out:
# AMERICAN MEDICAL POLITICAL ACTION COMMITTEE    769
# AMERICAN DENTAL POLITICAL ACTION COMMITTEE      96
# REPP, WARD W                                    89
# DEMOCRATIC CONGRESSIONAL DINNER COMMITTEE       65
# WILLIAMS, J D                                   64
#                                               ...
# MOYER, MONROE M                                  1
# NARVID, MICHAEL J                                1
# NORMAN, A E                                      1
# ASTON, ARTHUR                                    1
# STUART, HAROLD MRS                               1
# Name: NAME, Length: 217645, dtype: int64

# %% [markdown]
# ## 3

# %%
myDF.head() #head of the dataframe
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
myDF['Team']== 'Denmark' #how many team names is Denmark
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Team, Length: 271116, dtype: bool

# %%
myDF[myDF['Team']== 'Denmark']  #gives the rows which has Denmark
# Out:
#             ID                                               Name Sex   Age  \
# 2            3                                Gunnar Nielsen Aaby   M  24.0
# 1303       734                                 Otto Mnsted Acthon   M  30.0
# 1304       734                                 Otto Mnsted Acthon   M  30.0
# 1305       734                                 Otto Mnsted Acthon   M  34.0
# 1306       734                                 Otto Mnsted Acthon   M  34.0
# ...        ...                                                ...  ..   ...
# 270204  135176                                Peter Hermann Zobel   M  24.0
# 270205  135176                                Peter Hermann Zobel   M  24.0
# 270563  135322  Nathalie Xenia Margareta Benedikte zu Sayn-Wit...   F  33.0
# 270565  135322  Nathalie Xenia Margareta Benedikte zu Sayn-Wit...   F  37.0
# 270566  135322  Nathalie Xenia Margareta Benedikte zu Sayn-Wit...   F  37.0
#
# ...

# %%
len(myDF[myDF['Team']== 'Denmark']) #how many rows are in total for denmark
# Out:
# 3424

# %%
myDF[myDF['Team']== 'Denmark'].shape #no. of rows & column
# Out:
# (3424, 15)

# %%
myDF[myDF['Team']== 'Denmark'].shape[0]
# Out:
# 3424

# %%
myDF.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
myDF['Team'].str.contains('Denmark')
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Team, Length: 271116, dtype: bool

# %%
myDF[myDF['Team'].str.contains('Denmark')] # which column contains exaclty Denmark
# Out:
#             ID                                               Name Sex   Age  \
# 2            3                                Gunnar Nielsen Aaby   M  24.0
# 3            4                               Edgar Lindenau Aabye   M  34.0
# 1303       734                                 Otto Mnsted Acthon   M  30.0
# 1304       734                                 Otto Mnsted Acthon   M  30.0
# 1305       734                                 Otto Mnsted Acthon   M  34.0
# ...        ...                                                ...  ..   ...
# 270204  135176                                Peter Hermann Zobel   M  24.0
# 270205  135176                                Peter Hermann Zobel   M  24.0
# 270563  135322  Nathalie Xenia Margareta Benedikte zu Sayn-Wit...   F  33.0
# 270565  135322  Nathalie Xenia Margareta Benedikte zu Sayn-Wit...   F  37.0
# 270566  135322  Nathalie Xenia Margareta Benedikte zu Sayn-Wit...   F  37.0
#
# ...

# %%
myDF[myDF['Team'].str.contains('Denmark')]['Team'].value_counts() #to count the column team that has & hasn't Denmark
# Out:
# Denmark              3424
# Denmark-2              30
# Denmark-1              30
# Denmark/Sweden          6
# Miss Denmark 1964       2
# Denmark-3               2
# Denmark-4               2
# Name: Team, dtype: int64

# %%
myDF[myDF['Team'].str.contains('Denmark')].shape[0] #how many times denamrk are in total
# Out:
# 3496

# %%
len(myDF[myDF['Team'].str.contains('Denmark')])
# Out:
# 3496

# %%
myDF[(myDF['Team'].str.contains('Denmark')) 
     & (myDF['Team']!= 'Denmark')] 
#to get Denmark which is other than Denmark or anyother value contains the work denmark
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 3            4               Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 9065      4988                     Jrgen Arenholt   M  35.0     NaN     NaN
# 11971     6521              Einar Christian Bache   M  26.0     NaN     NaN
# 64290    32932                 Jens Dyrlv Eriksen   M  26.0   191.0    83.0
# 64291    32932                 Jens Dyrlv Eriksen   M  26.0   191.0    83.0
# ...        ...                                ...  ..   ...     ...     ...
# 238372  119531                      Axel Thayssen   M  27.0     NaN     NaN
# 239365  119981                    Marlene Thomsen   F  21.0   175.0     NaN
# 246169  123268                       Einer Ulrich   M  27.0     NaN     NaN
# 249861  125128  Majken Grethe Vange (-Hildebrand)   F  24.0   175.0    68.0
# 261705  130945    Charles Gustav Wilhelm Winckler   M  33.0     NaN     NaN
#
# ...

# %%
myDF[(myDF['Team'].str.contains('Denmark')) 
     & (myDF['Team']!= 'Denmark')]['Team'].value_counts()
#to check the value and hoe many times it occurs
# Out:
# Denmark-2            30
# Denmark-1            30
# Denmark/Sweden        6
# Miss Denmark 1964     2
# Denmark-3             2
# Denmark-4             2
# Name: Team, dtype: int64

# %%
myDF[(myDF['Team'].str.contains('Denmark')) 
     & (myDF['Team']!= 'Denmark')]['Team'].shape[0]
#to check the value and hoe many times it occurs all together
# Out:
# 72

# %%
len(myDF[(myDF['Team'].str.contains('Denmark')) 
     & (myDF['Team']!= 'Denmark')]) 
#to get which is not exalty Denmark but contains denmark
# Out:
# 72

# %% [markdown]
# ## 4

# %%
import pandas as pd

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/election/itcont1980.txt", header=None, sep='|') 
#putting header as none because the data does not have any header

# %%
myDF.columns = ["CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID"]
#giving headings to each column to make it more readable.

# %%
myDF.head()
# Out:
#      CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI    IMAGE_NUM TRANSACTION_TP  \
# 0  C00078279         A    M11               P  80031492155            22Y
# 1  C00078279         A    M11             NaN  79031415137             15
# 2  C00078279         A    M11             NaN  79031415137             15
# 3  C00078279         A    M11             NaN  79031415137             15
# 4  C00078287         A     Q1             NaN  79031231889             15
#
#    ENTITY_TP               NAME     CITY STATE  ...         EMPLOYER  \
# 0        NaN      MCKENNON, K R  MIDLAND    MI  ...              NaN
# 1        NaN        OREFFICE, P  MIDLAND    MI  ...  DOW CHEMICAL CO
# 2        NaN          DOWNEY, J  MIDLAND    MI  ...  DOW CHEMICAL CO
# 3        NaN           BLAIR, E  MIDLAND    MI  ...  DOW CHEMICAL CO
# 4        NaN  BLANCHARD, JOHN A  CHICAGO    IL  ...              NaN
#
#   OCCUPATION  TRANSACTION_DT  TRANSACTION_AMT  OTHER_ID TRAN_ID  FILE_NUM  \
# ...

# %%
myDF['STATE']
# Out:
# 0         MI
# 1         MI
# 2         MI
# 3         MI
# 4         IL
#           ..
# 308691    CA
# 308692    CA
# 308693    LA
# 308694    LA
# 308695    OK
# Name: STATE, Length: 308696, dtype: object

# %%
myDF['STATE'].value_counts() 
#to get Which value appears in the "state" column the most times
# Out:
# CA    37069
# TX    34862
# NY    25669
# IL    15895
# FL    15576
#       ...
# 01        3
# AS        2
# TU        1
# BE        1
# EL        1
# Name: STATE, Length: 61, dtype: int64

# %%
myDF['NAME']
# Out:
# 0              MCKENNON, K R
# 1                OREFFICE, P
# 2                  DOWNEY, J
# 3                   BLAIR, E
# 4          BLANCHARD, JOHN A
#                  ...
# 308691      PLEMAN, THOMAS J
# 308692    SHEINBAUM, STANLEY
# 308693     PHILLIPS, LEONARD
# 308694     PHILLIPS, BETTY S
# 308695    STUART, HAROLD MRS
# Name: NAME, Length: 308696, dtype: object

# %%
myDF['NAME'].value_counts() 
#to get Which value appears in the "Name" column the most times
# Out:
# AMERICAN MEDICAL POLITICAL ACTION COMMITTEE    769
# AMERICAN DENTAL POLITICAL ACTION COMMITTEE      96
# REPP, WARD W                                    89
# DEMOCRATIC CONGRESSIONAL DINNER COMMITTEE       65
# WILLIAMS, J D                                   64
#                                               ...
# MOYER, MONROE M                                  1
# NARVID, MICHAEL J                                1
# NORMAN, A E                                      1
# ASTON, ARTHUR                                    1
# STUART, HAROLD MRS                               1
# Name: NAME, Length: 217645, dtype: int64

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## 5

# %%
myDF.head()
# Out:
#      CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI    IMAGE_NUM TRANSACTION_TP  \
# 0  C00078279         A    M11               P  80031492155            22Y
# 1  C00078279         A    M11             NaN  79031415137             15
# 2  C00078279         A    M11             NaN  79031415137             15
# 3  C00078279         A    M11             NaN  79031415137             15
# 4  C00078287         A     Q1             NaN  79031231889             15
#
#    ENTITY_TP               NAME     CITY STATE  ...         EMPLOYER  \
# 0        NaN      MCKENNON, K R  MIDLAND    MI  ...              NaN
# 1        NaN        OREFFICE, P  MIDLAND    MI  ...  DOW CHEMICAL CO
# 2        NaN          DOWNEY, J  MIDLAND    MI  ...  DOW CHEMICAL CO
# 3        NaN           BLAIR, E  MIDLAND    MI  ...  DOW CHEMICAL CO
# 4        NaN  BLANCHARD, JOHN A  CHICAGO    IL  ...              NaN
#
#   OCCUPATION  TRANSACTION_DT  TRANSACTION_AMT  OTHER_ID TRAN_ID  FILE_NUM  \
# ...

# %%
pd.concat([myDF['CITY'], myDF['STATE']], axis=1) #concat is used to show city & state together
# Out:
#                    CITY STATE
# 0               MIDLAND    MI
# 1               MIDLAND    MI
# 2               MIDLAND    MI
# 3               MIDLAND    MI
# 4               CHICAGO    IL
# ...                 ...   ...
# 308691  WESTLAKE ISLAND    CA
# 308692      LOS ANGELES    CA
# 308693       SHREVEPORT    LA
# 308694       SHREVEPORT    LA
# 308695            TULSA    OK
#
# [308696 rows x 2 columns]

# %%
pd.concat([myDF['CITY'], myDF['STATE']], axis=1).value_counts() 
#to count maximun.
# Out:
# CITY           STATE
# NEW YORK       NY       13860
# HOUSTON        TX       10146
# DALLAS         TX        6437
# WASHINGTON     DC        5890
# LOS ANGELES    CA        5866
#                         ...
# KENSINGTON     KS           1
# KENSINGTON DR  MD           1
# KENT WOODLAND  CA           1
# KENTILWORTH    IL           1
# [NCHORAGE      AK           1
# Length: 19521, dtype: int64

# %%
pd.concat([myDF['CITY'], myDF['STATE']], axis=1).value_counts(dropna = False) 
#to get the empty values we put dropna as False
# Out:
# CITY         STATE
# NEW YORK     NY       13860
# NaN          NaN      11582
# HOUSTON      TX       10146
# DALLAS       TX        6437
# WASHINGTON   DC        5890
#                       ...
# KENTON       TN           1
# KENTONVILLE  MA           1
# KENWOOD      MD           1
# KENYON       RI           1
# LONDON, SW1  NaN          1
# Length: 19967, dtype: int64

# %%
pd.concat([myDF['CITY'], myDF['STATE']], axis=1).value_counts(dropna = False).head(5)
#to get maximun city state including null values
# Out:
# CITY        STATE
# NEW YORK    NY       13860
# NaN         NaN      11582
# HOUSTON     TX       10146
# DALLAS      TX        6437
# WASHINGTON  DC        5890
# dtype: int64
