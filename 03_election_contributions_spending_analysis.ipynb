# %% [markdown]
# ## Practice

# %%
import pandas as pd #importing pandas library as pd

# %%
#Reading the dataset and giving the column title to the data

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/election/itcont1980.txt", header=None, sep='|')

# %%
myDF.columns = ["CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID"]

# %%
myDF.groupby('STATE')['TRANSACTION_AMT'].sum() #summing the transation amount in the data accourding the state
# Out:
# STATE
# 01       1550
# AK     531485
# AL    2596149
# AR     954867
# AS       1500
#        ...
# WA    1872939
# WI    1342009
# WV     414924
# WY     504073
# ZZ     302079
# Name: TRANSACTION_AMT, Length: 61, dtype: int64

# %%
pd.set_option('display.max_rows',None) #to see all of the rows

# %%
myDF.groupby('STATE')['TRANSACTION_AMT'].sum()
# Out:
# STATE
# 01        1550
# AK      531485
# AL     2596149
# AR      954867
# AS        1500
# AZ     2178217
# BE         750
# CA    24085171
# CO     2708667
# CT     5328197
# CZ         950
# DC     5689543
# DE      595008
# EL        1000
# FL    10514203
# GA     4201705
# GU       29835
# HI      610401
# IA     1279935
# ID      543468
# IL     9105545
# IN     2518579
# KS     2230356
# KY     1536043
# LA     4394374
# MA     4233203
# MD     2660154
# ME      311825
# MI     4585088
# MN     2454049
# MO     3211817
# MS     1147941
# MT      288802
# NC     1644856
# ND      119115
# NE      508252
# NH      861868
# NJ     4489040
# NM      668358
# NV     1490702
# NY    18673301
# OH     7237330
# OK     5047135
# OR     1093271
# PA     5705339
# PR      385311
# RI      495636
# SC     1371766
# SD      295014
# TN     3043735
# TU         250
# TX    24472610
# UT      681255
# VA     2830422
# VI       75350
# VT      207943
# WA     1872939
# WI     1342009
# ...

# %% [markdown]
# ## 1

# %%
import pandas as pd

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/flights/subset/1990.csv")

# %%
pd.set_option('display.max_columns',None) #to see all of the coulmns

# %%
myDF.head() #to see the heading of the dataset
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1990      1           3          3   1707.0        1630   1755.0
# 1  1990      1           4          4   1706.0        1630   1807.0
# 2  1990      1           5          5   1629.0        1630   1715.0
# 3  1990      1           6          6   1633.0        1630   1718.0
# 4  1990      1           8          1   1630.0        1630   1726.0
#
#    CRSArrTime UniqueCarrier  FlightNum  TailNum  ActualElapsedTime  \
# 0        1723            US         29      NaN               48.0
# 1        1723            US         29      NaN               61.0
# 2        1723            US         29      NaN               46.0
# 3        1723            US         29      NaN               45.0
# 4        1723            US         29      NaN               56.0
#
#    CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  TaxiIn  \
# ...

# %%
myDF.groupby('Origin')['DepDelay'].mean() #to check the average departure delay
# Out:
# Origin
# ABE     5.004711
# ABQ     7.319594
# ACY     4.770252
# AGS     6.651299
# ALB     5.984751
# AMA     5.508656
# ANC     8.637353
# ATL     9.415189
# ATW     2.368217
# AUS     5.222057
# AVL     3.716092
# AVP     4.768055
# AZO     0.353526
# BDL     5.665549
# BET     8.071429
# BFL     4.649267
# BGM     2.595817
# BGR     5.765192
# BHM     5.269186
# BIL     2.946204
# BIS     1.882645
# BLI     6.096548
# BNA     5.626634
# BOI     5.032379
# BOS     8.421899
# BTM     4.675177
# BTR     7.052183
# BTV     5.865498
# BUF     6.086890
# BUR     3.869012
# BWI     6.065282
# BZN     6.301133
# CAE     5.938786
# CAK     3.802326
# CCR     2.061719
# CDV     4.325000
# CHA     3.607541
# CHO     3.092257
# CHS     5.016764
# CID     5.644542
# CLE     6.453564
# CLT     6.583503
# CMH     5.399658
# CMI     2.057385
# COS     3.573390
# CPR     0.310121
# CRP     6.984426
# CRW     5.063939
# CSG     6.475345
# CVG     6.917004
# DAB     5.872600
# DAL     9.187273
# ...

# %%
myDF.groupby('Origin')['ArrDelay'].mean() #to check the average arrival delay for flights
# Out:
# Origin
# ABE     2.721649
# ABQ     7.211509
# ACY     2.583001
# AGS     6.767631
# ALB     5.423677
# AMA     6.205330
# ANC     9.962569
# ATL     9.640582
# ATW    -1.722656
# AUS     4.809975
# AVL     3.280035
# AVP     4.236833
# AZO     1.065132
# BDL     3.920238
# BET     6.878049
# BFL     5.698357
# BGM     2.094496
# BGR     7.856190
# BHM     5.355751
# BIL     4.076475
# BIS     1.624052
# BLI     7.926127
# BNA     4.755178
# BOI     4.461201
# BOS     7.793923
# BTM     5.938746
# BTR     8.245807
# BTV     5.481669
# BUF     6.468036
# BUR     2.544822
# BWI     4.642260
# BZN     6.767802
# CAE     6.276551
# CAK     3.112137
# CCR     1.711825
# CDV     5.010294
# CHA     4.364577
# CHO     1.779436
# CHS     4.178007
# CID     5.181071
# CLE     6.323688
# CLT     6.677079
# CMH     6.487426
# CMI    -0.427358
# COS     4.878025
# CPR     1.114312
# CRP     8.974235
# CRW     5.388175
# CSG    10.612426
# CVG     8.362737
# DAB     6.264856
# DAL     8.935751
# ...

# %% [markdown]
# ## 2

# %%
#reading the grocery store file

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")

# %%
#assigning the column names

# %%
myDF.columns = ["BASKET_NUM", "HSHD_NUM", "PURCHASE", "PRODUCT_NUM", "SPEND", "UNITS", "STORE_R", "WEEK_NUM", "YEAR"]

# %%
myDF.head() #printing the entire dataset
# Out:
#    BASKET_NUM  HSHD_NUM   PURCHASE  PRODUCT_NUM  SPEND  UNITS  STORE_R  \
# 0          24      1809  03-JAN-16      5817389  -1.50     -1  SOUTH
# 1          24      1809  03-JAN-16      5829886  -1.50     -1  SOUTH
# 2          34      1253  03-JAN-16       539501   2.19      1  EAST
# 3          60      1595  03-JAN-16      5260099   0.99      1  WEST
# 4          60      1595  03-JAN-16      4535660   2.50      2  WEST
#
#    WEEK_NUM  YEAR
# 0         1  2016
# 1         1  2016
# 2         1  2016
# 3         1  2016
# 4         1  2016

# %%
myDF.groupby('STORE_R')['SPEND'].sum() #to find the sum of the amount spend in each store
# Out:
# STORE_R
# CENTRAL     8897305.14
# EAST       11699446.86
# SOUTH       7957920.77
# WEST        9680106.54
# Name: SPEND, dtype: float64

# %%
pd.set_option('display.max_rows', None) #to get all the rows of output

# %%
myDF.groupby('STORE_R')['SPEND'].sum()
# Out:
# STORE_R
# CENTRAL     8897305.14
# EAST       11699446.86
# SOUTH       7957920.77
# WEST        9680106.54
# Name: SPEND, dtype: float64

# %% [markdown]
# ##  3

# %%
# to find the total money spent in 2016 & 2017

# %%
myDF.groupby('YEAR')['SPEND'].sum()
# Out:
# YEAR
# 2016    19051720.01
# 2017    19183059.30
# Name: SPEND, dtype: float64

# %% [markdown]
# ## 4

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/olympics/athlete_events.csv")

# %%
myDF.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
myDF.groupby('NOC')['Height'].mean() #to find the average height of athletes in each country
# Out:
# NOC
# AFG    170.592593
# AHO    177.294118
# ALB    173.000000
# ALG    174.702869
# AND    173.703704
# ANG    178.204082
# ANT    175.121739
# ANZ    176.730769
# ARG    176.604722
# ARM    171.937799
# ARU    173.219512
# ASA    175.666667
# AUS    176.874017
# AUT    177.369686
# AZE    172.717391
# BAH    177.440678
# BAN    166.187500
# BAR    176.598958
# BDI    172.631579
# BEL    176.143175
# BEN    173.683333
# BER    177.405797
# BHU    166.517241
# BIH    178.633929
# BIZ    175.054795
# BLR    174.256440
# BOH    174.000000
# BOL    171.295652
# BOT    175.809524
# BRA    177.637147
# BRN    173.424528
# BRU    166.111111
# BUL    172.830911
# BUR    176.000000
# CAF    179.276596
# CAM    166.719298
# CAN    174.978716
# CAY    179.506849
# CGO    174.585366
# CHA    176.558824
# CHI    174.986989
# CHN    172.602743
# CIV    176.415094
# CMR    173.634615
# COD    175.358209
# COK    171.324324
# COL    169.915220
# COM    170.866667
# CPV    175.888889
# ...

# %% [markdown]
# ## 5

# %%
myDF.groupby('Sport')['Height'].mean() #to find the average height of athelets in each sport
# Out:
# Sport
# Aeronautics                         NaN
# Alpine Skiing                173.489052
# Alpinism                            NaN
# Archery                      173.203085
# Art Competitions             174.644068
# Athletics                    176.256268
# Badminton                    174.178803
# Baseball                     182.599291
# Basketball                   190.869879
# Basque Pelota                       NaN
# Beach Volleyball             186.144954
# Biathlon                     174.034766
# Bobsleigh                    181.437500
# Boxing                       172.825688
# Canoeing                     178.539568
# Cricket                             NaN
# Croquet                             NaN
# Cross Country Skiing         173.249185
# Curling                      174.203125
# Cycling                      176.108826
# Diving                       166.634264
# Equestrianism                174.375272
# Fencing                      177.164177
# ...
