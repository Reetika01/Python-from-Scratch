# %% [markdown]
# ## 1

# %% [markdown]
# Part (a)

# %%
import pandas as pd  #import the library

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/death_records/DeathRecords.csv") #Reading the dataset

# %%
myDF.head() #to view the data in the dataset
# Out:
#    Id  ResidentStatus  Education1989Revision  Education2003Revision  \
# 0   1               1                      0                      2
# 1   2               1                      0                      2
# 2   3               1                      0                      7
# 3   4               1                      0                      6
# 4   5               1                      0                      3
#
#    EducationReportingFlag  MonthOfDeath Sex  AgeType  Age  \
# 0                       1             1   M        1   87
# 1                       1             1   M        1   58
# 2                       1             1   F        1   75
# 3                       1             1   M        1   74
# 4                       1             1   M        1   64
#
#    AgeSubstitutionFlag  ...  CauseRecode39  NumberOfEntityAxisConditions  \
# 0                    0  ...             24                             1
# ...

# %%
subset_F= myDF[(myDF['Sex']=='F') & (myDF['Sex'].notnull())] #subset of the data where sex is F

# %%
subset_F.head() #check the head of the new subset
# Out:
#     Id  ResidentStatus  Education1989Revision  Education2003Revision  \
# 2    3               1                      0                      7
# 5    6               1                      0                      5
# 8    9               1                      0                      3
# 10  11               1                      0                      3
# 12  13               1                      0                      4
#
#     EducationReportingFlag  MonthOfDeath Sex  AgeType  Age  \
# 2                        1             1   F        1   75
# 5                        1             1   F        1   93
# 8                        1             1   F        1   86
# 10                       1             1   F        1   79
# 12                       1             1   F        1   85
#
#     AgeSubstitutionFlag  ...  CauseRecode39  NumberOfEntityAxisConditions  \
# 2                     0  ...             28                             2
# ...

# %% [markdown]
# Part (b)

# %%
subset_F['Age'].value_counts().sort_index() #female data with the missing values
# Out:
# Age
# 1      3164
# 2      2100
# 3      1346
# 4       937
# 5       820
#        ...
# 111      24
# 112       5
# 113       6
# 114       5
# 999     216
# Name: count, Length: 115, dtype: int64

# %%
import matplotlib.pyplot as plt #to make the graph

# %%
plt.plot(subset_F['Age'].value_counts().sort_index()) #cleaned dataset plot.

# %%
plt.plot(subset_F['Age'].sort_index()) #plot of the table with missing values.

# %% [markdown]
# Part(c)

# %%
clean_subset_F= subset_F[subset_F['Age'] !=999] #cleaning the subset

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(clean_subset_F['Age'].value_counts().sort_index()) #plot of the clean data of Age where gender is female.

# %% [markdown]
# ## 2

# %%
import pandas as pd  #import the library

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")

# %%
myDF.columns = ["BASKET_NUM", "HSHD_NUM", "PURCHASE", "PRODUCT_NUM", "SPEND", "UNITS", "STORE_R", "WEEK_NUM", "YEAR"]

# %%
myDF.head()
# Out:
#    BASKET_NUM  HSHD_NUM   PURCHASE  PRODUCT_NUM  SPEND  UNITS  STORE_R  \
# 0          24      1809  03-JAN-16      5817389  -1.50     -1  SOUTH
# 1          24      1809  03-JAN-16      5829886  -1.50     -1  SOUTH
# 2          34      1253  03-JAN-16       539501   2.19      1  EAST
# 3          60      1595  03-JAN-16      5260099   0.99      1  WEST
# 4          60      1595  03-JAN-16      4535660   2.50      2  WEST
#
#    WEEK_NUM  YEAR
# 0         1  2016
# 1         1  2016
# 2         1  2016
# 3         1  2016
# 4         1  2016

# %%
refundsDF = myDF[myDF['SPEND']<0] #rows where spend column is negative

# %%
refundsDF.head()
# Out:
#      BASKET_NUM  HSHD_NUM   PURCHASE  PRODUCT_NUM  SPEND  UNITS  STORE_R  \
# 0            24      1809  03-JAN-16      5817389  -1.50     -1  SOUTH
# 1            24      1809  03-JAN-16      5829886  -1.50     -1  SOUTH
# 92         4955      2570  06-JAN-16      5391980  -0.38      1  WEST
# 354       28557      3153  22-JAN-16      5184651  -3.42      9  CENTRAL
# 761       62654      4172  15-FEB-16       300529  -0.71      1  EAST
#
#      WEEK_NUM  YEAR
# 0           1  2016
# 1           1  2016
# 92          1  2016
# 354         3  2016
# 761         7  2016

# %%
store_refunds_table= refundsDF['STORE_R'].value_counts() #to create the table of unique store R

# %%
store_refunds_table.head() #dsplay the table of store R and their counts.
# Out:
# STORE_R
# WEST       3952
# EAST       3269
# CENTRAL    2750
# SOUTH      2675
# Name: count, dtype: int64

# %% [markdown]
# ## 3

# %%
import pandas as pd  #import the library

# %%
myDF= pd.read_csv("/anvil/projects/tdm/data/beer/reviews_sample.csv")

# %%
myDF.head()
# Out:
#    beer_id         username        date  \
# 0   271781     bluejacket74  2017-03-17
# 1   125646          _dirty_  2017-12-21
# 2   125646          CJDUBYA  2017-12-21
# 3   125646  GratefulBeerGuy  2017-12-20
# 4   125646         LukeGude  2017-12-20
#
#                                                 text  look  smell  taste  \
# 0     750 ml bottle, 2016 vintage, bottle #304 of...  4.00   4.00   4.00
# 1                                                     4.50   4.50   4.50
# 2                                                     4.75   4.75   4.75
# 3     0% 16 oz can. Funny story: As I finally wal...  4.75   4.75   4.50
# 4     Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50   4.25
#
#    feel  overall  score
# 0  4.25     4.00   4.03
# 1  4.50     4.50   4.50
# 2  4.75     4.75   4.75
# 3  4.50     4.50   4.58
# 4  4.25     4.25   4.31

# %%
subset = myDF[(myDF['score'] !=5)  & (myDF['overall']==5)] #creating a subset where score !=5 & overall ==5

# %%
lines = subset.shape[0] #to count the no. of lines in the subset

# %%
print(f"Number of lines in the subset: {lines}") #to print the no. of lines in the subset
# Out:
# Number of lines in the subset: 12436

# %% [markdown]
# ## 4

# %%
import pandas as pd  #import the library

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/election/itcont1980.txt", header=None, sep='|')

# %%
myDF.columns = ["CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID"]

# %%
myDF.head()
# Out:
#      CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI    IMAGE_NUM TRANSACTION_TP  \
# 0  C00078279         A    M11               P  80031492155            22Y
# 1  C00078279         A    M11             NaN  79031415137             15
# 2  C00078279         A    M11             NaN  79031415137             15
# 3  C00078279         A    M11             NaN  79031415137             15
# 4  C00078287         A     Q1             NaN  79031231889             15
#
#    ENTITY_TP               NAME     CITY STATE  ...         EMPLOYER  \
# 0        NaN      MCKENNON, K R  MIDLAND    MI  ...              NaN
# 1        NaN        OREFFICE, P  MIDLAND    MI  ...  DOW CHEMICAL CO
# 2        NaN          DOWNEY, J  MIDLAND    MI  ...  DOW CHEMICAL CO
# 3        NaN           BLAIR, E  MIDLAND    MI  ...  DOW CHEMICAL CO
# 4        NaN  BLANCHARD, JOHN A  CHICAGO    IL  ...              NaN
#
#   OCCUPATION  TRANSACTION_DT  TRANSACTION_AMT  OTHER_ID TRAN_ID  FILE_NUM  \
# ...

# %%
missing_dt_subset = myDF[myDF['TRANSACTION_DT'].isna()] #to print rows which has missing transaction dt

# %%
missing_dt_counts = missing_dt_subset['NAME'].value_counts() #to count the name

# %%
print("Number of missing TRANSACTION_DT entries per person:")
print(missing_dt_counts) #to print the number of missing people with count.
# Out:
# Number of missing TRANSACTION_DT entries per person:
# NAME
# SCHECK, RICHARD HERBERT    6
# WOLFF, GARY W.             2
# CURCIO, BARBARA G          1
# Name: count, dtype: int64

# %%
#identifying the person with six missing trabsactions.

# %%
person_with_six_missing = missing_dt_counts[missing_dt_counts == 6].index[0]
print(f"\nThe person who made 6 donations with a missing TRANSACTION_DT is: {person_with_six_missing}")
# Out:
# The person who made 6 donations with a missing TRANSACTION_DT is: SCHECK, RICHARD HERBERT
