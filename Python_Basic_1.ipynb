# %% [markdown]
# # Basic of Python

# %% [markdown]
# ## 1

# %%
#importing library to import data

# %%
import pandas as pd

# %%
#to read the dataset

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/flights/subset/airports.csv")

# %%
#to view the first 5 data present in the dataset

# %%
myDF.head()
# Out:
#   iata               airport              city state country        lat  \
# 0  00M              Thigpen        Bay Springs    MS     USA  31.953765
# 1  00R  Livingston Municipal        Livingston    TX     USA  30.685861
# 2  00V           Meadow Lake  Colorado Springs    CO     USA  38.945749
# 3  01G          Perry-Warsaw             Perry    NY     USA  42.741347
# 4  01J      Hilliard Airpark          Hilliard    FL     USA  30.688012
#
#          long
# 0  -89.234505
# 1  -95.017928
# 2 -104.569893
# 3  -78.052081
# 4  -81.905944

# %% [markdown]
# ## 2

# %%
#Using shape to check the total rows & column

# %%
myDF.shape
# Out:
# (3376, 7)

# %%
myDF.tail() #to get the rows from the datset
# Out:
#      iata                    airport         city state country        lat  \
# 3371  ZEF            Elkin Municipal        Elkin    NC     USA  36.280024
# 3372  ZER  Schuylkill Cty/Joe Zerbey   Pottsville    PA     USA  40.706449
# 3373  ZPH      Zephyrhills Municipal  Zephyrhills    FL     USA  28.228065
# 3374  ZUN                 Black Rock         Zuni    NM     USA  35.083227
# 3375  ZZV       Zanesville Municipal   Zanesville    OH     USA  39.944458
#
#             long
# 3371  -80.786069
# 3372  -76.373147
# 3373  -82.155916
# 3374 -108.791777
# 3375  -81.892105

# %% [markdown]
# #to display the airports in New York

# %%
myDF[(myDF['city'] == 'New York') & (myDF['state'] == 'NY')]
# Out:
#      iata                                    airport      city state country  \
# 589   6N5                         E 34th St Heliport  New York    NY     USA
# 590   6N7                 New York Skyports Inc. SPB  New York    NY     USA
# 1915  JFK                        John F Kennedy Intl  New York    NY     USA
# 1929  JRA  Port Authority-W 30th St Midtown Heliport  New York    NY     USA
# 1930  JRB       Downtown Manhattan/Wall St. Heliport  New York    NY     USA
# 2061  LGA                                  LaGuardia  New York    NY     USA
#
#             lat       long
# 589   40.742602 -73.972083
# 590   40.733991 -73.972916
# 1915  40.639751 -73.778926
# 1929  40.754546 -74.007084
# 1930  40.701214 -74.009028
# 2061  40.777243 -73.872609

# %%
#to display the airports in Indianapolis

# %%
myDF[(myDF['city'] == 'Indianapolis') & (myDF['state'] == 'IN')]
# Out:
#       iata                     airport          city state country        lat  \
# 1440   EYE         Eagle Creek Airpark  Indianapolis    IN     USA  39.830709
# 1870  IN03       Indianapolis Downtown  Indianapolis    IN     USA  39.765876
# 1871   IND  Indianapolis International  Indianapolis    IN     USA  39.717329
# 2311   MQJ               Mount Comfort  Indianapolis    IN     USA  39.843486
# 3161   TYQ          Indianapolis Terry  Indianapolis    IN     USA  40.030650
# 3209   UMP   Indianapolis Metropolitan  Indianapolis    IN     USA  39.935203
#
#            long
# 1440 -86.294381
# 1870 -86.148875
# 1871 -86.294384
# 2311 -85.897064
# 3161 -86.251437
# 3209 -86.044953

# %%
#to display the airports in Houston

# %%
myDF[(myDF['city'] == 'Houston') & (myDF['state'] == 'TX')]
# Out:
#      iata                       airport     city state country        lat  \
# 1318  DWH    David Wayne Hooks Memorial  Houston    TX     USA  30.061861
# 1366  EFD                    Ellington   Houston    TX     USA  29.607333
# 1748  HOU               William P Hobby  Houston    TX     USA  29.645419
# 1837  IAH  George Bush Intercontinental  Houston    TX     USA  29.980472
# 1898  IWS                  West Houston  Houston    TX     USA  29.818194
# 2114  LVJ                       Clover   Houston    TX     USA  29.521306
# 2941  SGR    Sugar Land Municipal/Hull   Houston    TX     USA  29.622253
# 3004  SPX                  Houston-Gulf  Houston    TX     USA  29.508361
#
#            long
# 1318 -95.552778
# 1366 -95.158750
# 1748 -95.278889
# 1837 -95.339722
# 1898 -95.672611
# 2114 -95.242167
# 2941 -95.656529
# 3004 -95.051333

# %% [markdown]
# ##  3

# %%
#to view the states

# %%
myDF['state']
# Out:
# 0       MS
# 1       TX
# 2       CO
# 3       NY
# 4       FL
#         ..
# 3371    NC
# 3372    PA
# 3373    FL
# 3374    NM
# 3375    OH
# Name: state, Length: 3376, dtype: object

# %%
#to get how many airports in each state & to print of first 5

# %%
myDF['state'].value_counts()
# Out:
# AK    263
# TX    209
# CA    205
# OK    102
# FL    100
# OH    100
# GA     97
# NY     97
# MI     94
# MN     89
# IL     88
# WI     84
# KS     78
# IA     78
# MO     74
# AR     74
# AL     73
# NE     73
# NC     72
# MS     72
# MT     71
# PA     71
# TN     70
# IN     65
# WA     65
# AZ     59
# OR     57
# SD     57
# LA     55
# ND     52
# SC     52
# NM     51
# KY     50
# CO     49
# VA     47
# ID     37
# UT     35
# NJ     35
# ME     34
# NV     32
# WY     32
# MA     30
# WV     24
# MD     18
# HI     16
# CT     15
# NH     14
# VT     13
# PR     11
# RI      6
# DE      5
# VI      5
# CQ      4
# AS      3
# DC      1
# GU      1
# Name: state, dtype: int64

# %%
myDF['state'].value_counts().head()
# Out:
# AK    263
# TX    209
# CA    205
# OK    102
# FL    100
# Name: state, dtype: int64

# %%
#to count state & importing matplotlib

# %%
mycounts = myDF['state'].value_counts().head()

# %%
import matplotlib.pyplot as plt

# %%
#Now using the above we can make a bar chart

# %%
plt.bar(mycounts.index, mycounts)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ##  4

# %%
#to import icecream dataset

# %%
myDF1 = pd.read_csv("/anvil/projects/tdm/data/icecream/combined/products.csv")

# %%
myDF1['brand']
# Out:
# 0           bj
# 1           bj
# 2           bj
# 3           bj
# 4           bj
#         ...
# 236    breyers
# 237    breyers
# 238    breyers
# 239    breyers
# 240    breyers
# Name: brand, Length: 241, dtype: object

# %%
#to count how many times each brand came in column

# %%
myDF1['brand'].value_counts()
# Out:
# hd         70
# breyers    69
# bj         57
# talenti    45
# Name: brand, dtype: int64

# %%
myDF2 = pd.read_csv("/anvil/projects/tdm/data/icecream/combined/reviews.csv")

# %%
myDF2['brand'] #to print all the brand
# Out:
# 0             bj
# 1             bj
# 2             bj
# 3             bj
# 4             bj
#           ...
# 21669    breyers
# 21670    breyers
# 21671    breyers
# 21672    breyers
# 21673    breyers
# Name: brand, Length: 21674, dtype: object

# %%
myDF1['brand'].value_counts() #to count how many times each brand came in column
# Out:
# hd         70
# breyers    69
# bj         57
# talenti    45
# Name: brand, dtype: int64

# %% [markdown]
# ## 5

# %%
import matplotlib.pyplot as plt

# %%
#to show how many times brand occurs in product dataset

# %%
mycounts = myDF1['brand'].value_counts()

# %%
plt.bar(mycounts.index, mycounts)
# Out:
# <BarContainer object of 4 artists>

# %%
mycounts = myDF2['brand'].value_counts()

# %%
#to show how many times brand occurs in reviews dataset

# %%
plt.bar(mycounts.index, mycounts)
# Out:
# <BarContainer object of 4 artists>
